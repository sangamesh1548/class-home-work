# %%
import pandas as pd
df=pd.read_csv(r"https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1714 entries, 0 to 1713
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Package      1714 non-null   object
#  1   Item         1714 non-null   object
#  2   Title        1714 non-null   object
#  3   Rows         1714 non-null   int64
#  4   Cols         1714 non-null   int64
#  5   n_binary     1714 non-null   int64
#  6   n_character  1714 non-null   int64
#  7   n_factor     1714 non-null   int64
#  8   n_logical    1714 non-null   int64
#  9   n_numeric    1714 non-null   int64
#  10  CSV          1714 non-null   object
#  11  Doc          1714 non-null   object
# dtypes: int64(7), object(5)
# memory usage: 160.8+ KB

# %%
df.rename(columns={'Rows':'num1','Cols':'num2','n_binary':'num3','n_character':'num4'},inplace=True)

# %%
df['new_cloumns']=df['num1']+df['num2']+df['num3']+df['num4']

# %%
df[df['num1']>600]['num1']
# Out:
# 0         601
# 10       4739
# 13      28155
# 14       7986
# 15      20999
#         ...
# 1664     2894
# 1669     4060
# 1679     7240
# 1680     1056
# 1684    14018
# Name: num1, Length: 427, dtype: int64

# %%
df['Package'].astype('object').count()
# Out:
# 1714

# %%
df[df['Item'].isnull()==True]['Item'].sum()
# Out:
# 0

# %%
df.groupby('Title')['num1'].mean()
# Out:
# Title
# "Let Them Watch TV"                                                 2377.0
# 'May' in Federalist Papers                                             7.0
# 'colors()' in Luv space                                              657.0
# 100 m Swimming World Records                                          62.0
# 12 cognitive variables from Cattell (1963)                            12.0
#                                                                      ...
# smoking                                                                6.0
# sorption data set                                                    192.0
# titanic                                                             1316.0
# titanicgrp                                                            12.0
# van Langren's Data on Longitude Distance between Toledo and Rome      36.5
# Name: num1, Length: 1580, dtype: float64

# %%
df['cloumn']=df['num2'].apply(lambda x:x*2)

# %%
df.loc[0:20:2,['Package','Item']]
# Out:
#    Package             Item
# 0      AER          Affairs
# 2      AER        BankWages
# 4      AER        BondYield
# 6      AER        CASchools
# 8      AER      CigarettesB
# 10     AER  CollegeDistance
# 12     AER          CPS1985
# 14     AER          CPSSW04
# 16     AER           CPSSW8
# 18     AER        CPSSW9298
# 20     AER       CreditCard

# %%
a=df[df['num1']>600].index
df.iloc[a][['Item']]
# Out:
#                  Item
# 0             Affairs
# 10    CollegeDistance
# 13            CPS1988
# 14            CPSSW04
# 15             CPSSW3
# ...               ...
# 1664        wavesurge
# 1669       population
# 1679              who
# 1680   world_bank_pop
# 1684       Bundesliga
#
# [427 rows x 1 columns]

# %%
df[df['Package'].isnull()]['Package']
# Out:
# Series([], Name: Package, dtype: object)

# %%
for i in df['CSV'].to_list():
    df['https']=i[0:26]

# %%
for i in df['CSV'].to_list():
    df['github']=i[27:]

# %%
df.drop('Doc',axis=1,inplace=True)

# %%
df.to_csv('read.csv',index=True)

# %%
df
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  num1  num2  num3  \
# 0                      Fair's Extramarital Affairs Data   601     9     2
# 1                     Consumer Price Index in Argentina    80     2     0
# 2                                            Bank Wages   474     4     2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5     0
# 4                                       Bond Yield Data    60     2     0
# ...                                                 ...   ...   ...   ...
# 1709                                   UK Soccer Scores    25     3     0
# ...

# %%
url="https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt"

# %%
df=pd.read_csv(url)

# %%
dict1={}
lst=[]
for i in df['name calories sodium alcohol cost']:
    lst.append(i.split())
 

    
for i in range(len(lst)):
    print(dict1.update({i:lst[i]}))
    
df=pd.DataFrame(dict1)
df.T
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
#                        0    1   2    3     4
# 0              Budweiser  144  15  4.7  0.43
# 1                Schlitz  151  19  4.9  0.43
# 2              Lowenbrau  157  15  0.9  0.48
# 3            Kronenbourg  170   7  5.2  0.73
# 4               Heineken  152  11  5.0  0.77
# 5          Old_Milwaukee  145  23  4.6  0.28
# 6             Augsberger  175  24  5.5  0.40
# 7   Srohs_Bohemian_Style  149  27  4.7  0.42
# 8            Miller_Lite   99  10  4.3  0.43
# 9        Budweiser_Light  113   8  3.7  0.40
# 10                 Coors  140  18  4.6  0.44
# 11           Coors_Light  102  15  4.1  0.46
# 12        Michelob_Light  135  11  4.2  0.50
# 13                 Becks  150  19  4.7  0.76
# 14                 Kirin  149   6  5.0  0.79
# 15     Pabst_Extra_Light   68  15  2.3  0.38
# 16                 Hamms  139  19  4.4  0.43
# ...

# %%
df=pd.DataFrame(dict1)

# %%
df1=df.T
df1
# Out:
#                        0    1   2    3     4
# 0              Budweiser  144  15  4.7  0.43
# 1                Schlitz  151  19  4.9  0.43
# 2              Lowenbrau  157  15  0.9  0.48
# 3            Kronenbourg  170   7  5.2  0.73
# 4               Heineken  152  11  5.0  0.77
# 5          Old_Milwaukee  145  23  4.6  0.28
# 6             Augsberger  175  24  5.5  0.40
# 7   Srohs_Bohemian_Style  149  27  4.7  0.42
# 8            Miller_Lite   99  10  4.3  0.43
# 9        Budweiser_Light  113   8  3.7  0.40
# 10                 Coors  140  18  4.6  0.44
# 11           Coors_Light  102  15  4.1  0.46
# 12        Michelob_Light  135  11  4.2  0.50
# 13                 Becks  150  19  4.7  0.76
# 14                 Kirin  149   6  5.0  0.79
# 15     Pabst_Extra_Light   68  15  2.3  0.38
# 16                 Hamms  139  19  4.4  0.43
# 17   Heilemans_Old_Style  144  24  4.9  0.43
# 18   Olympia_Goled_Light   72   6  2.9  0.46
# 19         Schlitz_Light   97   7  4.2  0.47

# %%
df1.rename(columns={0:'col1',1:'col2',2:'col3',3:'col4',4:'col5'},inplace=True)

# %%
df1
# Out:
#                     col1 col2 col3 col4  col5
# 0              Budweiser  144   15  4.7  0.43
# 1                Schlitz  151   19  4.9  0.43
# 2              Lowenbrau  157   15  0.9  0.48
# 3            Kronenbourg  170    7  5.2  0.73
# 4               Heineken  152   11  5.0  0.77
# 5          Old_Milwaukee  145   23  4.6  0.28
# 6             Augsberger  175   24  5.5  0.40
# 7   Srohs_Bohemian_Style  149   27  4.7  0.42
# 8            Miller_Lite   99   10  4.3  0.43
# 9        Budweiser_Light  113    8  3.7  0.40
# 10                 Coors  140   18  4.6  0.44
# 11           Coors_Light  102   15  4.1  0.46
# 12        Michelob_Light  135   11  4.2  0.50
# 13                 Becks  150   19  4.7  0.76
# 14                 Kirin  149    6  5.0  0.79
# 15     Pabst_Extra_Light   68   15  2.3  0.38
# 16                 Hamms  139   19  4.4  0.43
# 17   Heilemans_Old_Style  144   24  4.9  0.43
# 18   Olympia_Goled_Light   72    6  2.9  0.46
# ...

# %%
df1.reset_index(drop=True,inplace=True)

# %%
df1.drop_duplicates()
# Out:
#                     col1 col2 col3 col4  col5
# 0              Budweiser  144   15  4.7  0.43
# 1                Schlitz  151   19  4.9  0.43
# 2              Lowenbrau  157   15  0.9  0.48
# 3            Kronenbourg  170    7  5.2  0.73
# 4               Heineken  152   11  5.0  0.77
# 5          Old_Milwaukee  145   23  4.6  0.28
# 6             Augsberger  175   24  5.5  0.40
# 7   Srohs_Bohemian_Style  149   27  4.7  0.42
# 8            Miller_Lite   99   10  4.3  0.43
# 9        Budweiser_Light  113    8  3.7  0.40
# 10                 Coors  140   18  4.6  0.44
# 11           Coors_Light  102   15  4.1  0.46
# 12        Michelob_Light  135   11  4.2  0.50
# 13                 Becks  150   19  4.7  0.76
# 14                 Kirin  149    6  5.0  0.79
# 15     Pabst_Extra_Light   68   15  2.3  0.38
# 16                 Hamms  139   19  4.4  0.43
# 17   Heilemans_Old_Style  144   24  4.9  0.43
# 18   Olympia_Goled_Light   72    6  2.9  0.46
# ...

# %%
df1['col6']=df1['col4']+df1['col5']

# %%
df1['col6']=df1['col6'].astype('object')

# %%
df1
# Out:
#                     col1 col2 col3 col4  col5     col6
# 0              Budweiser  144   15  4.7  0.43  4.70.43
# 1                Schlitz  151   19  4.9  0.43  4.90.43
# 2              Lowenbrau  157   15  0.9  0.48  0.90.48
# 3            Kronenbourg  170    7  5.2  0.73  5.20.73
# 4               Heineken  152   11  5.0  0.77  5.00.77
# 5          Old_Milwaukee  145   23  4.6  0.28  4.60.28
# 6             Augsberger  175   24  5.5  0.40  5.50.40
# 7   Srohs_Bohemian_Style  149   27  4.7  0.42  4.70.42
# 8            Miller_Lite   99   10  4.3  0.43  4.30.43
# 9        Budweiser_Light  113    8  3.7  0.40  3.70.40
# 10                 Coors  140   18  4.6  0.44  4.60.44
# 11           Coors_Light  102   15  4.1  0.46  4.10.46
# 12        Michelob_Light  135   11  4.2  0.50  4.20.50
# 13                 Becks  150   19  4.7  0.76  4.70.76
# 14                 Kirin  149    6  5.0  0.79  5.00.79
# 15     Pabst_Extra_Light   68   15  2.3  0.38  2.30.38
# ...

# %%
url='https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv'

# %%
df2=pd.read_csv(url)
df2[df2['Year']>200]['Murder'].count()
# Out:
# 55

# %%
a=df2['Year']>1960

# %%
b= df2['Year']<=2000

# %%
c=a & b.index

# %%
df2.iloc[c]['Vehicle_Theft'].sum()
# Out:
# 27613718

# %%
df2.set_index(df2['Year'],inplace=True,drop=False)

# %%
df2
# Out:
#       Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960  1960   179323175   3384200   288460   3095700    9110          17190
# 1961  1961   182992000   3488000   289390   3198600    8740          17220
# 1962  1962   185771000   3752200   301510   3450700    8530          17550
# 1963  1963   188483000   4109500   316970   3792500    8640          17650
# 1964  1964   191141000   4564600   364220   4200400    9360          21420
# 1965  1965   193526000   4739400   387390   4352000    9960          23410
# 1966  1966   195576000   5223500   430180   4793300   11040          25820
# 1967  1967   197457000   5903400   499930   5403500   12240          27620
# 1968  1968   199399000   6720200   595010   6125200   13800          31670
# 1969  1969   201385000   7410900   661870   6749000   14760          37170
# 1970  1970   203235298   8098000   738820   7359200   16000          37990
# ...

# %%
url3="https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

# %%
df3=pd.read_table(url3)
for j in df3['item_price']:
    df3['new_col']=j[1:]

# %%
df3['new_col']=df3['new_col'].astype(float)

# %%
df3['new']=df3['new_col']+df3['quantity']

# %%
df3
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  new_col  \
# 0                                                   NaN     $2.39      8.75
# ...
